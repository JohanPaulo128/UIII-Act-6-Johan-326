# %% [markdown]
# <a href="https://colab.research.google.com/github/JohanPaulo128/UIII-Act-6-Johan-326/blob/main/UIII_Act_6_Proyecto_de_simulaci%C3%B3n_de_inteligencia_artificial_con_if%2C_else%2C_elif_y_while_Johan_0016.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Johan Paulo Aros Reveles Fecha 19/Mayo/2026
# ## NL = 04

# %%
print("--- Simulador de IA: Evaluador de Crédito ---")
continuar = "si"

while continuar == "si":
    ingresos = int(input("Ingresa tus ingresos mensuales: "))
    edad = int(input("Ingresa tu edad: "))

    if edad < 18:
        print("Lo siento, debes ser mayor de edad.")
    elif ingresos > 5000:
        print("¡Felicidades! Calificas para la Tarjeta Platinum.")
    elif ingresos >= 2000:
        print("Calificas para la Tarjeta Clásica.")
    else:
        print("Por ahora no podemos ofrecerte una tarjeta.")

    continuar = input("¿Quieres evaluar a otra persona? (si/no): ")
    print("Programa realiado por Johan Paulo Nl = 04")
# Out:
# --- Simulador de IA: Evaluador de Crédito ---
# Ingresa tus ingresos mensuales: 10000
# Ingresa tu edad: 15
# Lo siento, debes ser mayor de edad.
# ¿Quieres evaluar a otra persona? (si/no): si
# Programa realiado por Johan Paulo Nl = 04
# Ingresa tus ingresos mensuales: 100000
# Ingresa tu edad: 18
# ¡Felicidades! Calificas para la Tarjeta Platinum.
# ¿Quieres evaluar a otra persona? (si/no): si
# Programa realiado por Johan Paulo Nl = 04
# Ingresa tus ingresos mensuales: 2100
# Ingresa tu edad: 18
# Calificas para la Tarjeta Clásica.
# ¿Quieres evaluar a otra persona? (si/no): no
# Programa realiado por Johan Paulo Nl = 04

# %%
print("--- Simulador de IA: Evaluador de Crédito ---")
continuar = "si"

while continuar == "si":
    ingresos = int(input("Ingresa tus ingresos mensuales: "))
    edad = int(input("Ingresa tu edad: "))

    if edad < 18:
        print("Lo siento, debes ser mayor de edad.")
    elif ingresos > 5000:
        print("¡Felicidades! Calificas para la Tarjeta Platinum.")
    elif ingresos >= 2000:
        print("Calificas para la Tarjeta Clásica.")
    else:
        print("Por ahora no podemos ofrecerte una tarjeta.")

    continuar = input("¿Quieres evaluar a otra persona? (si/no): ")
    print("Programa realiado por Johan Paulo Nl = 04")
# Out:
# --- Simulador de IA: Evaluador de Crédito ---
# Ingresa tus ingresos mensuales: 2100
# Ingresa tu edad: 18
# Calificas para la Tarjeta Clásica.
# ¿Quieres evaluar a otra persona? (si/no): si
# Programa realiado por Johan Paulo Nl = 04
# Ingresa tus ingresos mensuales: 5100
# Ingresa tu edad: 18
# ¡Felicidades! Calificas para la Tarjeta Platinum.
# ¿Quieres evaluar a otra persona? (si/no): no
# Programa realiado por Johan Paulo Nl = 04

# %%
print("--- Simulador de IA: Evaluador de Crédito ---")
continuar = "si"

while continuar == "si":
    ingresos = int(input("Ingresa tus ingresos mensuales: "))
    edad = int(input("Ingresa tu edad: "))

    if edad < 18:
        print("Lo siento, debes ser mayor de edad.")
    elif ingresos > 5000:
        print("¡Felicidades! Calificas para la Tarjeta Platinum.")
    elif ingresos >= 2000:
        print("Calificas para la Tarjeta Clásica.")
    else:
        print("Por ahora no podemos ofrecerte una tarjeta.")

    continuar = input("¿Quieres evaluar a otra persona? (si/no): ")
    print("Programa realiado por Johan Paulo Nl = 04")
# Out:
# --- Simulador de IA: Evaluador de Crédito ---
# Ingresa tus ingresos mensuales: 5100
# Ingresa tu edad: 18
# ¡Felicidades! Calificas para la Tarjeta Platinum.
# ¿Quieres evaluar a otra persona? (si/no): si
# Programa realiado por Johan Paulo Nl = 04
# Ingresa tus ingresos mensuales: 2100
# Ingresa tu edad: 18
# Calificas para la Tarjeta Clásica.
# ¿Quieres evaluar a otra persona? (si/no): si
# Programa realiado por Johan Paulo Nl = 04
# Ingresa tus ingresos mensuales: 2100
# Ingresa tu edad: 17
# Lo siento, debes ser mayor de edad.
# ¿Quieres evaluar a otra persona? (si/no): no
# Programa realiado por Johan Paulo Nl = 04

# %%
print("--- Simulador de IA: Evaluador de Crédito ---")
continuar = "si"

while continuar == "si":
    ingresos = int(input("Ingresa tus ingresos mensuales: "))
    edad = int(input("Ingresa tu edad: "))

    if edad < 18:
        print("Lo siento, debes ser mayor de edad.")
    elif ingresos > 5000:
        print("¡Felicidades! Calificas para la Tarjeta Platinum.")
    elif ingresos >= 2000:
        print("Calificas para la Tarjeta Clásica.")
    else:
        print("Por ahora no podemos ofrecerte una tarjeta.")

    continuar = input("¿Quieres evaluar a otra persona? (si/no): ")
    print("Programa realiado por Johan Paulo Nl = 04")
# Out:
# --- Simulador de IA: Evaluador de Crédito ---
# Ingresa tus ingresos mensuales: 1000
# Ingresa tu edad: 18
# Por ahora no podemos ofrecerte una tarjeta.
# ¿Quieres evaluar a otra persona? (si/no): si
# Programa realiado por Johan Paulo Nl = 04
# Ingresa tus ingresos mensuales: 2100
# Ingresa tu edad: 18
# Calificas para la Tarjeta Clásica.
# ¿Quieres evaluar a otra persona? (si/no): si
# Programa realiado por Johan Paulo Nl = 04
# Ingresa tus ingresos mensuales: 5100
# Ingresa tu edad: 18
# ¡Felicidades! Calificas para la Tarjeta Platinum.
# ¿Quieres evaluar a otra persona? (si/no): no
# Programa realiado por Johan Paulo Nl = 04

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/JohanPaulo128/UIII-Act-6-Johan-326/refs/heads/main/InfoTarjeta.png)
